# %% [markdown]
# #  Data Science Tools and Ecosystem

# %% [markdown]
# ##  In this notebook, Data Science Tools and Ecosystem are Summarized

# %% [markdown]
# # **Objectives**:
# - popular languages for Data Scientis (python, R, scala, and Julia)
# - polulat Data Science Tools (Jupyter Notebook, SciKit-Learn, TensorFlow, and GitHub)
# - popular Libraries for Data Scientist (Pandas, Numpy, Matplotlib, tidyr,dplyr, and ggplot2)

# %% [markdown]
# # some of the popular laguages that Data Scientists use are:
# 1. Python
# 2. R
# 3. Julia
# 4. SQL
# 5. Scala

# %% [markdown]
# # some of the commonly used libraries used by Data Scientists includes:
# 1. Numpy
# 2. Matplotlib
# 3. ggplot2
# 4. Seabon
# 5. dplyr
# 6. tidyr
# 7. scikit-learn
# 8. airflow

# %% [markdown]
# # Data Science Tools
# |Data Science Tools|
# |---------------|
# |Jupyter Notebook|
# |TensorFlow|
# |SciKit-Learn|
# |GitHub|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This a simple arithmetic expression to multiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author:
# Sakeenat Olanike Fatai
